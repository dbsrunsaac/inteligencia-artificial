# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn import datasets

# %%
dataset=datasets.load_breast_cancer()
# print(dataset)

# dataset = pd.read_csv('breast_cancer.csv')

# X = dataset.iloc[:, 2:32].values
# y = dataset.iloc[:, 1].values

#descripcion del dataset
print(dataset.keys())
# print(dataset.DESCR)

X=dataset.data
y=dataset.target

# Dividir el data set en conjunto de entrenamiento y conjunto de testing
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# Escalado de variables
from sklearn.preprocessing import StandardScaler
escalar = StandardScaler()
X_train = escalar.fit_transform(X_train)
X_test = escalar.transform(X_test)

# Ajustar el modelo de Regresión Logística en el Conjunto de Entrenamiento
from sklearn.linear_model import LogisticRegression
algoritmo = LogisticRegression(random_state = 0)
algoritmo.fit(X_train, y_train)

print(f"intercepto (b): {algoritmo.intercept_}")
print(f"pendiente (w): {algoritmo.coef_}")

# Predicción de los resultados con el Conjunto de Testing
y_pred  = algoritmo.predict(X_test)

# Elaborar una matriz de confusión
from sklearn.metrics import confusion_matrix
matriz = confusion_matrix(y_test, y_pred)
print('Matriz de confusion')
print(matriz)

#Presicion
from sklearn.metrics import precision_score
presicion=precision_score(y_test, y_pred)
print('Presicion del modelo')
print(presicion)

#Accuracy
from sklearn.metrics import accuracy_score
exactitud=accuracy_score(y_test, y_pred)
print('Exactitud del modelo')
print(exactitud)

#Sensibilidad
from sklearn.metrics import recall_score
sensibilidad=recall_score(y_test, y_pred)
print('Sensibilidad del modelo')
print(sensibilidad)

#F1 score
from sklearn.metrics import f1_score
puntajef1=f1_score(y_test, y_pred)
print('Puntaje F1 del modelo')
print(puntajef1)
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])
# intercepto (b): [0.69145634]
# pendiente (w): [[-0.63302982 -0.63357587 -0.60983301 -0.61357403 -0.2830236   0.15538842
#   -0.83634008 -0.75718098 -0.03483722  0.4442677  -1.11098134  0.42761384
#   -0.76428423 -0.85584848 -0.09745095  0.85800787 -0.17391833 -0.19475722
#    0.51892508  0.73214856 -0.95983605 -1.20003307 -0.85016631 -0.87497553
#   -1.06329415  0.12430969 -0.87706142 -0.62295191 -0.72840393 -0.36343047]]
# Matriz de confusion
# [[52  4]
#  [ 0 87]]
# Presicion del modelo
# 0.9560439560439561
# Exactitud del modelo
# 0.972027972027972
# Sensibilidad del modelo
# 1.0
# Puntaje F1 del modelo
# 0.9775280898876404
